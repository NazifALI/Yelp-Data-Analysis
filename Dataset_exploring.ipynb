# %%
import pandas as pd
import csv
import warnings
# warnings.simplefilter(action = "ignore", category = SettingWithCopyWarning)
warnings.simplefilter("ignore", pd.core.common.SettingWithCopyWarning)

raw_business = pd.read_csv('./dataset/yelp_academic_dataset_business.csv', sep=',', index_col=None )
print 'shape=',raw_business.shape
print raw_business.columns
raw_business.head()
# Out:
# shape= (85901, 98)
# Index([u'attributes.Ambience.divey', u'attributes.Dietary Restrictions.vegan',
#        u'attributes.Happy Hour', u'hours.Thursday.open',
#        u'attributes.Order at Counter',
#        u'attributes.Hair Types Specialized In.africanamerican',
#        u'attributes.Hair Types Specialized In.kids', u'attributes.BYOB',
#        u'hours.Friday.open', u'attributes.Good For.latenight',
#        u'attributes.Outdoor Seating', u'attributes.Alcohol',
#        u'attributes.Ambience.classy', u'attributes.By Appointment Only',
#        u'attributes.Parking.lot', u'business_id',
#        u'attributes.Ambience.touristy', u'attributes.Corkage',
#        u'hours.Tuesday.open', u'attributes.Good For.brunch', u'categories',
#        u'attributes.Waiter Service', u'hours.Monday.open', u'name',
#        u'attributes.Parking.street', u'attributes.Ambience.hipster',
#        u'attributes.BYOB/Corkage',
#        u'attributes.Hair Types Specialized In.straightperms',
#        u'attributes.Music.live', u'attributes.Dietary Restrictions.dairy-free',
#        u'attributes.Music.background_music', u'attributes.Price Range',
#        u'attributes.Good For.breakfast', u'attributes.Parking.garage',
#        u'attributes.Music.karaoke', u'attributes.Good For Dancing',
#        u'review_count', u'attributes.Hair Types Specialized In.asian',
#        u'state', u'attributes.Accepts Credit Cards', u'hours.Friday.close',
#        u'attributes.Good For.lunch', u'attributes.Parking.valet',
#        u'attributes.Take-out', u'full_address', u'hours.Thursday.close',
#        u'attributes.Hair Types Specialized In.coloring',
#        u'attributes.Good For.dessert', u'attributes.Music.video',
#        u'attributes.Dietary Restrictions.halal',
#        u'attributes.Takes Reservations', u'hours.Saturday.open',
#        u'attributes.Ages Allowed', u'attributes.Ambience.trendy',
#        u'attributes.Delivery', u'hours.Wednesday.close', u'attributes.Wi-Fi',
#        u'open', u'city', u'attributes.Wheelchair Accessible',
#        u'attributes.Dietary Restrictions.gluten-free', u'stars',
#        u'attributes.Dietary Restrictions.kosher', u'type',
#        u'attributes.Caters', u'attributes.Ambience.intimate', u'latitude',
#        u'attributes.Good For.dinner', u'attributes.Coat Check', u'longitude',
#        u'hours.Monday.close',
#        u'attributes.Hair Types Specialized In.extensions',
#        u'hours.Tuesday.close', u'hours.Saturday.close',
#        u'attributes.Good for Kids', u'attributes.Parking.validated',
#        u'hours.Sunday.open', u'attributes.Accepts Insurance',
#        u'attributes.Music.dj', u'attributes.Dietary Restrictions.soy-free',
#        u'attributes.Has TV', u'hours.Sunday.close',
#        u'attributes.Ambience.casual',
#        u'attributes.Hair Types Specialized In.perms',
#        u'attributes.Dogs Allowed', u'attributes.Drive-Thru',
#        u'attributes.Dietary Restrictions.vegetarian', u'hours.Wednesday.open',
#        u'attributes.Noise Level', u'attributes.Smoking', u'attributes.Attire',
#        u'attributes.Hair Types Specialized In.curly',
#        u'attributes.Good For Groups', u'neighborhoods',
#        u'attributes.Open 24 Hours', u'attributes.Ambience.romantic',
#        u'attributes.Music.jukebox', u'attributes.Ambience.upscale'],
#       dtype='object')
#   attributes.Ambience.divey attributes.Dietary Restrictions.vegan  \
# 0                     False                                   NaN
# 1                       NaN                                   NaN
# 2                       NaN                                   NaN
# 3                      True                                   NaN
# 4                       NaN                                   NaN
#
#   attributes.Happy Hour hours.Thursday.open attributes.Order at Counter  \
# 0                   NaN               11:00                         NaN
# 1                  True                 NaN                         NaN
# 2                   NaN                 NaN                         NaN
# 3                 False               10:00                         NaN
# 4                   NaN               11:00                         NaN
#
#   attributes.Hair Types Specialized In.africanamerican  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   attributes.Hair Types Specialized In.kids attributes.BYOB hours.Friday.open  \
# 0                                       NaN             NaN             11:00
# 1                                       NaN             NaN               NaN
# 2                                       NaN             NaN               NaN
# 3                                       NaN             NaN             10:00
# 4                                       NaN             NaN             11:00
#
#   attributes.Good For.latenight             ...              \
# 0                         False             ...
# 1                           NaN             ...
# 2                           NaN             ...
# 3                         False             ...
# 4                           NaN             ...
#
#   attributes.Noise Level attributes.Smoking attributes.Attire  \
# 0                average                NaN            casual
# 1                    NaN                NaN               NaN
# 2                    NaN                NaN               NaN
# 3                average                 no            casual
# 4                    NaN                NaN               NaN
#
#   attributes.Hair Types Specialized In.curly attributes.Good For Groups  \
# 0                                        NaN                       True
# 1                                        NaN                       True
# 2                                        NaN                        NaN
# 3                                        NaN                       True
# 4                                        NaN                       True
#
#   neighborhoods attributes.Open 24 Hours attributes.Ambience.romantic  \
# 0            []                      NaN                        False
# 1            []                      NaN                          NaN
# 2            []                      NaN                          NaN
# 3            []                      NaN                        False
# 4            []                      NaN                          NaN
#
#   attributes.Music.jukebox attributes.Ambience.upscale
# 0                      NaN                       False
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                       False
# 4                      NaN                         NaN
#
# [5 rows x 98 columns]

# %%
raw_review = pd.read_csv('./dataset/yelp_academic_dataset_review.csv', sep=',', index_col=None )
print 'shape=',raw_review.shape
print raw_review.columns
raw_review.head()
# Out:
# shape= (2685066, 10)
# Index([u'user_id', u'review_id', u'text', u'votes.cool', u'business_id',
#        u'votes.funny', u'stars', u'date', u'type', u'votes.useful'],
#       dtype='object')
#                   user_id               review_id  \
# 0  PUFPaY9KxDAcGqfsorJp3Q  Ya85v4eqdd6k9Od8HbQjyA
# 1  Iu6AxdBYGR4A0wspR9BYHA  KPvLNJ21_4wbYNctrOwWdQ
# 2  auESFwWvW42h6alXgFxAXQ  fFSoGV46Yxuwbr3fHNuZig
# 3  qiczib2fO_1VBG8IoCGvVg  pVMIt0a_QsKtuDfWVfSk2A
# 4  qEE5EvV-f-s7yHC0Z4ydJQ  AEyiQ_Y44isJmNbMTyoMKQ
#
#                                                 text  votes.cool  \
# 0  Mr Hoagie is an institution. Walking in, it do...           0
# 1  Excellent food. Superb customer service. I mis...           0
# 2  Yes this place is a little out dated and not o...           0
# 3  PROS: Italian hoagie was delicious.  Friendly ...           0
# 4  First the only reason this place could possibl...           0
#
#               business_id  votes.funny  stars        date    type  \
# 0  5UmKMjUEUNdYWqANhGckJw            0      4  2012-08-01  review
# 1  5UmKMjUEUNdYWqANhGckJw            0      5  2014-02-13  review
# 2  5UmKMjUEUNdYWqANhGckJw            1      5  2015-10-31  review
# 3  5UmKMjUEUNdYWqANhGckJw            0      3  2015-12-26  review
# 4  5UmKMjUEUNdYWqANhGckJw            0      2  2016-04-08  review
#
#    votes.useful
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %%
review_of_business = raw_review[['business_id','text','stars','date','votes.cool','votes.funny','votes.useful']]
print 'shape=',review_of_business.shape
print review_of_business.columns
review_of_business.head()
# Out:
# shape= (2685066, 7)
# Index([u'business_id', u'text', u'stars', u'date', u'votes.cool',
#        u'votes.funny', u'votes.useful'],
#       dtype='object')
#               business_id                                               text  \
# 0  5UmKMjUEUNdYWqANhGckJw  Mr Hoagie is an institution. Walking in, it do...
# 1  5UmKMjUEUNdYWqANhGckJw  Excellent food. Superb customer service. I mis...
# 2  5UmKMjUEUNdYWqANhGckJw  Yes this place is a little out dated and not o...
# 3  5UmKMjUEUNdYWqANhGckJw  PROS: Italian hoagie was delicious.  Friendly ...
# 4  5UmKMjUEUNdYWqANhGckJw  First the only reason this place could possibl...
#
#    stars        date  votes.cool  votes.funny  votes.useful
# 0      4  2012-08-01           0            0             0
# 1      5  2014-02-13           0            0             0
# 2      5  2015-10-31           0            1             1
# 3      3  2015-12-26           0            0             0
# 4      2  2016-04-08           0            0             1

# %%
raw_tip = pd.read_csv('./dataset/yelp_academic_dataset_tip.csv', sep=',', index_col=None )
print 'shape=',raw_tip.shape
print raw_tip.columns
raw_tip.head()
# Out:
# shape= (648902, 6)
# Index([u'user_id', u'text', u'business_id', u'likes', u'date', u'type'], dtype='object')
#                   user_id                                               text  \
# 0  ZxdojCZgZhw36xuSGaryRg           Pizza is garbage. Hoagies are excellent.
# 1  -6rEfobYjMxpUWLNxszaxQ                             Don't waste your time.
# 2  5OumCBQ_MyQsltSdbMyunA  Not easy to find. Be sure to put in directions...
# 3  EZ0r9dKKtEGVx2CdnowPCw  Your GPS will not allow you to find this place...
# 4  xb6zEQCw9I-Gl0g06e1KsQ                              Great drink specials!
#
#               business_id  likes        date type
# 0  5UmKMjUEUNdYWqANhGckJw      0  2016-07-17  tip
# 1  cE27W9VPgO88Qxe4ol6y_g      0  2013-04-18  tip
# 2  mVHrayjG3uZ_RLHkLj-AMg      0  2016-02-22  tip
# 3  mVHrayjG3uZ_RLHkLj-AMg      1  2013-01-06  tip
# 4  KayYbHCt-RkbGcPdGOThNg      0  2013-12-03  tip

# %% [markdown]
# - yelp_academic_dataset_checkin.csv
# - yelp_academic_dataset_user.csv

# %%
raw_checkin = pd.read_csv('./dataset/yelp_academic_dataset_checkin.csv', sep=',', index_col=None )
print 'shape=',raw_checkin.shape
print raw_checkin.columns
raw_checkin.head()
# Out:
# shape= (61049, 170)
# Index([u'checkin_info.9-0', u'checkin_info.9-1', u'checkin_info.9-2',
#        u'checkin_info.9-3', u'checkin_info.9-4', u'checkin_info.9-5',
#        u'checkin_info.9-6', u'checkin_info.20-2', u'checkin_info.20-3',
#        u'checkin_info.20-0',
#        ...
#        u'checkin_info.6-1', u'checkin_info.6-0', u'checkin_info.3-1',
#        u'checkin_info.18-6', u'checkin_info.18-5', u'checkin_info.18-4',
#        u'checkin_info.18-3', u'checkin_info.18-2', u'checkin_info.18-1',
#        u'checkin_info.18-0'],
#       dtype='object', length=170)
#    checkin_info.9-0  checkin_info.9-1  checkin_info.9-2  checkin_info.9-3  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               1.0
# 3               NaN               1.0               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    checkin_info.9-4  checkin_info.9-5  checkin_info.9-6  checkin_info.20-2  \
# 0               NaN               1.0               NaN                NaN
# 1               3.0               2.0               NaN                NaN
# 2               NaN               NaN               NaN                NaN
# 3               5.0               NaN               NaN                NaN
# 4               NaN               NaN               NaN                NaN
#
#    checkin_info.20-3  checkin_info.20-0        ...          checkin_info.6-1  \
# 0                NaN                NaN        ...                       NaN
# 1                NaN                NaN        ...                       NaN
# 2                NaN                NaN        ...                       NaN
# 3                NaN                NaN        ...                       NaN
# 4                NaN                NaN        ...                       NaN
#
#    checkin_info.6-0  checkin_info.3-1  checkin_info.18-6 checkin_info.18-5  \
# 0               NaN               NaN                NaN               NaN
# 1               NaN               NaN                NaN               NaN
# 2               NaN               NaN                NaN               NaN
# 3               NaN               NaN                NaN               NaN
# 4               NaN               NaN                NaN               NaN
#
#    checkin_info.18-4  checkin_info.18-3  checkin_info.18-2  checkin_info.18-1  \
# 0                1.0                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                1.0                2.0                1.0                NaN
# 4                NaN                NaN                NaN                NaN
#
#    checkin_info.18-0
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 170 columns]

# %%
raw_user = pd.read_csv('./dataset/yelp_academic_dataset_user.csv', sep=',', index_col=None )
print 'shape=',raw_user.shape
print raw_user.columns
raw_user.head()
# Out:
# shape= (686556, 23)
# Index([u'yelping_since', u'compliments.plain', u'review_count', u'friends',
#        u'compliments.cute', u'compliments.writer', u'fans',
#        u'compliments.note', u'type', u'compliments.hot', u'compliments.cool',
#        u'compliments.profile', u'average_stars', u'compliments.more', u'elite',
#        u'name', u'user_id', u'votes.cool', u'compliments.list', u'votes.funny',
#        u'compliments.photos', u'compliments.funny', u'votes.useful'],
#       dtype='object')
#   yelping_since  compliments.plain  review_count  \
# 0       2004-10               25.0           108
# 1       2004-10              970.0          1292
# 2       2004-10               86.0           395
# 3       2004-10                NaN            11
# 4       2004-10                2.0            66
#
#                                              friends  compliments.cute  \
# 0  [u'rpOyqD_893cqmDAtJLbdog', u'4U9kSBLuBDU391x6...              15.0
# 1  [u'18kPq7GPye-YQ3LyKyAZPw', u'4U9kSBLuBDU391x6...             204.0
# 2  [u'18kPq7GPye-YQ3LyKyAZPw', u'rpOyqD_893cqmDAt...              22.0
# 3  [u'18kPq7GPye-YQ3LyKyAZPw', u'rpOyqD_893cqmDAt...               2.0
# 4  [u'rpOyqD_893cqmDAtJLbdog', u'HDQixQ-WZEV0LVPJ...               2.0
#
#    compliments.writer  fans  compliments.note  type  compliments.hot  \
# 0                 9.0    69              20.0  user             48.0
# 1               346.0  1345             611.0  user           1111.0
# 2                24.0   105              79.0  user             99.0
# 3                 NaN     2               NaN  user              NaN
# 4                 2.0     5               1.0  user              1.0
#
#        ...       compliments.more  \
# 0      ...                    3.0
# 1      ...                  137.0
# 2      ...                   18.0
# 3      ...                    NaN
# 4      ...                    1.0
#
#                                                elite       name  \
# 0                                       [2005, 2006]     Russel
# 1  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...     Jeremy
# 2  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...    Michael
# 3                                                 []        Ken
# 4                                             [2005]  Katherine
#
#                   user_id votes.cool compliments.list votes.funny  \
# 0  18kPq7GPye-YQ3LyKyAZPw        246              NaN         167
# 1  rpOyqD_893cqmDAtJLbdog      12091             38.0        8399
# 2  4U9kSBLuBDU391x6bxU-YA        657              4.0         722
# 3  fHtTaujcyKvXglE33Z5yIw          5              NaN           1
# 4  SIBCL7HBkrP4llolm4SC2A         16              NaN          13
#
#    compliments.photos  compliments.funny  votes.useful
# 0                14.0               11.0           282
# 1               361.0              594.0         15242
# 2                27.0               96.0          1349
# 3                 NaN                NaN            11
# 4                 NaN                NaN            37
#
# [5 rows x 23 columns]

# %% [markdown]
# ### The average stars for each state
# Try to find the average number of starts for each state in the dataset.

# %%
#bar plot
location_star = raw_business[['state','stars']]
star_for_state = location_star.groupby(['state'])
state_avg_star = star_for_state.mean()
state_avg_star['count'] = star_for_state.count()
print state_avg_star.shape, '= (x,y), x = Number of states ',
state_avg_star
# Out:
# (29, 2) = (x,y), x = Number of states
#           stars  count
# state
# AK     3.500000      1
# AL     2.000000      1
# AZ     3.710438  36500
# BW     3.771090   1055
# CA     3.000000      4
# EDH    3.820594   3297
# ELN    3.681818     11
# FIF    3.600000      5
# FL     4.000000      2
# HAM    4.500000      1
# IL     3.552599    808
# KHL    3.500000      1
# MLN    3.804348    161
# MN     5.000000      1
# NC     3.585662   6835
# NM     3.000000      1
# NTH    2.000000      1
# NV     3.690984  23591
# NW     4.500000      1
# ON     3.556604    530
# PA     3.717695   4086
# QC     3.692810   5591
# RP     4.083333     18
# SC     3.570769    325
# SCB    4.250000      2
# TAM    4.000000      1
# TX     3.833333      3
# WI     3.662427   3066
# XGL    3.000000      1

# %%
state_avg_star = state_avg_star[ state_avg_star['count']>10 ] # exclude rows that only has 3 count
state_avg_star = state_avg_star.sort_values(['stars'], ascending=False)
print state_avg_star.shape
state_avg_star
# Out:
# (14, 2)
#           stars  count
# state
# RP     4.083333     18
# EDH    3.820594   3297
# MLN    3.804348    161
# BW     3.771090   1055
# PA     3.717695   4086
# AZ     3.710438  36500
# QC     3.692810   5591
# NV     3.690984  23591
# ELN    3.681818     11
# WI     3.662427   3066
# NC     3.585662   6835
# SC     3.570769    325
# ON     3.556604    530
# IL     3.552599    808

# %%
### Setup for data visualization
import plotly.plotly as py
import plotly.graph_objs as go
import plotly

### You need to create a plotly account.
### Use the username API key  
plotly.tools.set_credentials_file(username='user', api_key='your key')

# %%
data = [go.Bar(
            x=state_avg_star.index,
            y=state_avg_star['stars']
    )]
layout = go.Layout(
    title='Average Stars for Each State',
    xaxis=dict(
        title='State names',
        tickangle=45,
        tickfont=dict(size=10),
    ),
    yaxis=dict(
        title='# of Stars',
        titlefont=dict(color='#1f77b4'),
        tickfont=dict(size=10,color='#1f77b4'), 
#         tick0 = 2,
#         dtick = 0.2
    ),    
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='AVG_star_for_state')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/100.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# - RP: Rhineland-Palatinate, GERMANY
# - EDH: Edinburgh, UK
# - MLN: Midlothian, UK
# - BW: Baden-Württemberg, GERMANY
#
# - QC: Quebec, Canada
# - ELN: ,UK
# - ON: Ontario, Canada
# - FIF: ,UK

# %%
location_count = raw_business[['state','city','stars']]
location_count = location_count.groupby(['state','city'])
location_stat = location_count.count()
location_stat = location_stat[ location_stat['stars']>10 ]
print location_stat.shape, '= (x,y), x = Number of cities '
location_stat
# Out:
# (120, 1) = (x,y), x = Number of cities
#                        stars
# state city
# AZ    Ahwatukee           12
#       Anthem             135
#       Apache Junction    186
#       Avondale           427
#       Buckeye            163
#       Carefree            54
#       Casa Grande        201
#       Cave Creek         266
#       Chandler          2701
#       Coolidge            21
#       El Mirage           63
#       Florence            46
#       Fountain Hills     204
#       Gila Bend           21
#       Gilbert           1940
#       Glendale          2048
#       Gold Canyon         42
#       Goodyear           507
#       Guadalupe           15
#       Higley              17
#       Laveen              96
#       Litchfield Park    120
#       Maricopa           165
#       Mesa              3637
#       New River           18
#       Paradise Valley     90
#       Peoria            1081
#       Phoenix          11851
#       Queen Creek        383
#       San Tan Valley     100
# ...                      ...
# QC    Dorval              43
#       Kirkland            26
#       Lachine             29
#       Lasalle             49
#       Laval              222
#       Longueuil           32
#       Mont-Royal          14
#       Montreal            95
#       Montr�al          4371
#       Outremont           35
#       Pierrefonds         26
#       Pointe-Claire       52
#       Saint-Lambert       11
#       Saint-Laurent       75
#       Saint-Leonard       25
#       Verdun             109
#       Westmount           59
# SC    Fort Mill          286
#       Tega Cay            13
# WI    Cottage Grove       20
#       De Forest           21
#       Fitchburg          136
#       Madison           2278
#       Mc Farland          17
#       McFarland           16
#       Middleton          222
#       Monona              85
#       Sun Prairie        129
#       Verona              62
#       Waunakee            41
#
# [120 rows x 1 columns]

# %% [markdown]
# From the analysis, we can know the following infomation.
# 1. Yelp dataset include data from 29 states. Some states are not in U.S..
#     * Waterloo, Canada
#     * Montreal, Canada
#     * Karlsruhe, Germany
#     * Edinburgh, UK  (EDH)
# 2. 464 cities are included in the Yelp dataset.

# %%
location_count = raw_business[['state','stars']]
location_count
# Out:
#       state  stars
# 0        PA    3.5
# 1        PA    3.0
# 2        PA    2.5
# 3        PA    4.5
# 4        PA    5.0
# 5        PA    4.0
# 6        PA    2.5
# 7        PA    4.0
# 8        PA    2.5
# 9        PA    4.0
# 10       PA    4.5
# 11       PA    3.5
# 12       PA    3.5
# 13       PA    4.0
# 14       PA    3.5
# 15       PA    3.0
# 16       PA    3.0
# 17       PA    4.0
# 18       PA    4.5
# 19       PA    4.0
# 20       PA    3.5
# 21       PA    3.5
# 22       PA    2.5
# 23       PA    4.5
# 24       PA    3.0
# 25       PA    2.5
# 26       PA    2.5
# 27       PA    3.5
# 28       PA    3.5
# 29       PA    3.0
# ...     ...    ...
# 85871    NV    5.0
# 85872    QC    2.5
# 85873    AZ    5.0
# 85874    AZ    4.0
# 85875    NV    5.0
# 85876    QC    4.5
# 85877    WI    4.5
# 85878    NV    5.0
# 85879    NC    5.0
# 85880    AZ    4.0
# 85881    AZ    4.0
# 85882    AZ    5.0
# 85883    NV    5.0
# 85884    AZ    5.0
# 85885    NV    3.0
# 85886    NV    3.5
# 85887    AZ    2.5
# 85888    NV    5.0
# 85889    AZ    3.5
# 85890    AZ    2.0
# 85891    AZ    2.5
# 85892    NV    2.0
# 85893    WI    4.0
# 85894    AZ    5.0
# 85895    NV    3.0
# 85896    NV    4.0
# 85897    AZ    3.5
# 85898    AZ    3.0
# 85899   EDH    4.0
# 85900    NC    2.5
#
# [85901 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))   # set the size of figure (x,y)

# durationUFO = cleanUFO.Duration.astype(float) 
# shapeUFO = cleanUFO.Shape 
ax = sns.boxplot(x=location_count['stars'], groupby=location_count['state']) 
# ax.set_yscale('log')
plt.xlabel('States', fontsize=20)
plt.ylabel('# of Star', fontsize=20)
plt.title('The Distribution of Stars for each State', fontsize=24)
plt.show()
# Out:
# /Users/PatrickYu/anaconda/envs/cs489/lib/python2.7/site-packages/seaborn/categorical.py:2171: UserWarning:
#
# The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.

# %% [markdown]
# ### Categories vs. Stars
# Next, we try to find the relationship between categories and stars.

# %%
category_stars = raw_business[['categories','stars']]
category_stars.head()
# Out:
#                                           categories  stars
# 0                     [u'Fast Food', u'Restaurants']    3.5
# 1                                     [u'Nightlife']    3.0
# 2            [u'Active Life', u'Mini Golf', u'Golf']    2.5
# 3  [u'Bars', u'American (New)', u'Nightlife', u'L...    4.5
# 4                          [u'Active Life', u'Golf']    5.0

# %%
US_tradition = category_stars[ category_stars['categories'].str.contains('Traditional')]
US_new = category_stars[ category_stars['categories'].str.contains('New')]
Mexican = category_stars[ category_stars['categories'].str.contains(u'Mexican')]
Indian = category_stars[ category_stars['categories'].str.contains(u'Indian')]
Italian = category_stars[ category_stars['categories'].str.contains(u'Italian')]
Chinese = category_stars[ category_stars['categories'].str.contains(u'Chinese')]

Cuban = category_stars[ category_stars['categories'].str.contains(u'Cuban')]
Brunch = category_stars[ category_stars['categories'].str.contains(u'Breakfast & Brunch')]
Fish = category_stars[ category_stars['categories'].str.contains(u'Fish & Chips')]
Mediterranean = category_stars[ category_stars['categories'].str.contains(u'Mediterranean')]

Mediterranean
# burgers.describe()
# Out:
#                                               categories  stars
# 182    [u'Bars', u'Mediterranean', u'Wine Bars', u'Ni...    4.0
# 193    [u'Portuguese', u'Mediterranean', u'Restaurants']    4.0
# 420         [u'Greek', u'Mediterranean', u'Restaurants']    3.5
# 424    [u'Greek', u'Mediterranean', u'Middle Eastern'...    3.0
# 605    [u'Middle Eastern', u'Mediterranean', u'Restau...    4.0
# 941    [u'Greek', u'American (Traditional)', u'Medite...    3.5
# 1104   [u'Wine Bars', u'Bars', u'Mediterranean', u'Ni...    3.5
# 1450        [u'Greek', u'Mediterranean', u'Restaurants']    3.5
# 1930   [u'Bakeries', u'Lebanese', u'Food', u'Mediterr...    4.5
# 2427        [u'Greek', u'Mediterranean', u'Restaurants']    3.5
# 2446   [u'Greek', u'Mediterranean', u'Sandwiches', u'...    3.5
# 2492   [u'Greek', u'Mediterranean', u'Sandwiches', u'...    3.5
# 2805   [u'Greek', u'Mediterranean', u'Middle Eastern'...    4.0
# 2922        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 2974        [u'Greek', u'Mediterranean', u'Restaurants']    3.5
# 3100        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 3220        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 3291   [u'American (New)', u'Mediterranean', u'Restau...    4.0
# 3379      [u'Restaurants', u'Mediterranean', u'Italian']    4.0
# 3516   [u'Italian', u'American (Traditional)', u'Medi...    4.0
# 3943        [u'Greek', u'Mediterranean', u'Restaurants']    4.5
# 4513        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 4744        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 4924   [u'Food', u'Middle Eastern', u'Grocery', u'Med...    4.5
# 5725   [u'Vegetarian', u'American (New)', u'Mediterra...    4.0
# 6426        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 7070        [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 7081        [u'Pizza', u'Mediterranean', u'Restaurants']    3.5
# 7298   [u'Mediterranean', u'Greek', u'Middle Eastern'...    4.0
# 7661      [u'Restaurants', u'Mediterranean', u'Italian']    3.0
# ...                                                  ...    ...
# 83000  [u'Falafel', u'Mediterranean', u'Sandwiches', ...    4.5
# 83073                 [u'Mediterranean', u'Restaurants']    3.5
# 83206  [u'Vegetarian', u'American (New)', u'Mediterra...    4.5
# 83325                 [u'Mediterranean', u'Restaurants']    4.5
# 83372       [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 83445  [u'Vegetarian', u'American (New)', u'Mediterra...    3.5
# 83451                 [u'Mediterranean', u'Restaurants']    4.0
# 83499  [u'Restaurants', u'Mediterranean', u'Barbeque'...    4.0
# 83580  [u'Coffee & Tea', u'Music Venues', u'Food', u'...    3.5
# 83596  [u'Greek', u'Italian', u'Mediterranean', u'Res...    4.0
# 83670  [u'Tapas Bars', u'Spanish', u'Mediterranean', ...    5.0
# 83859  [u'Tapas/Small Plates', u'Vegetarian', u'Medit...    4.0
# 83873  [u'Middle Eastern', u'Greek', u'Mediterranean'...    4.0
# 83941  [u'Mediterranean', u'Sandwiches', u'Restaurants']    4.5
# 84027  [u'Bars', u'Mediterranean', u'Wine Bars', u'Ni...    4.5
# 84037  [u'Portuguese', u'Spanish', u'Mediterranean', ...    4.0
# 84044                 [u'Mediterranean', u'Restaurants']    4.0
# 84095    [u'Mediterranean', u'Moroccan', u'Restaurants']    1.5
# 84327                 [u'Mediterranean', u'Restaurants']    4.5
# 84667  [u'Mediterranean', u'Sandwiches', u'Salad', u'...    5.0
# 84681       [u'Greek', u'Mediterranean', u'Restaurants']    4.5
# 85082       [u'Greek', u'Mediterranean', u'Restaurants']    4.0
# 85345  [u'Breakfast & Brunch', u'Turkish', u'Mediterr...    4.5
# 85571  [u'Food', u'Middle Eastern', u'Juice Bars & Sm...    4.5
# 85614  [u'Greek', u'Burgers', u'Mediterranean', u'Res...    4.5
# 85705  [u'Mediterranean', u'Middle Eastern', u'Restau...    4.5
# 85722                 [u'Mediterranean', u'Restaurants']    4.5
# 85739                 [u'Mediterranean', u'Restaurants']    4.5
# 85749  [u'Mexican', u'Mediterranean', u'Vegan', u'Res...    4.5
# 85841  [u'Food', u'Mediterranean', u'Juice Bars & Smo...    3.5
#
# [614 rows x 2 columns]

# %%
x_data = ['American (Traditional)', 'American (New)','Mexican', 'Indian','Italian','Chinese',
         'Cuban', 'Brunch', 'Fish & Chips', 'Mediterranean']

y_data = [US_tradition.stars, US_new.stars, Mexican.stars, Indian.stars, Italian.stars, Chinese.stars, 
          Cuban.stars, Brunch.stars, Fish.stars, Mediterranean.stars]

colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)',
         'rgba(123, 34, 23, 0.5)', 'rgba(27,66, 45, 0.5)', 'rgba(73, 126, 12, 0.5)', 'rgba(67, 210, 56, 0.5)']

traces = []

for xd, yd, cls in zip(x_data, y_data, colors):
        traces.append(go.Box(
            y=yd,
            name=xd,
#             boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
        ))

layout = go.Layout(
    title='Stars Distribution by Types of Restaurants',
    yaxis=dict(
        autorange=True,
        showgrid=True,
        zeroline=True,
        dtick=5,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
        zerolinecolor='rgb(255, 255, 255)',
        zerolinewidth=2,
    ),
    margin=dict(
        l=40,
        r=30,
        b=80,
        t=100,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
    showlegend=False
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig,filename='Stars Distribution by Types of Restaurants')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/122.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# It should include review_counts.

# %% [markdown]
# ## How many categories of business are in Yelp reviews?

# %%
print "Total number of business in the dataset: ", category_stars.shape
print 'Total number of unique categories: ', len( category_stars.categories.unique() )

category_find = raw_business[['categories','stars']]

category_count = []
category_name = ['Active Life', 'Arts & Entertainment','Automotive','Beauty & Spas','Education',
                'Event Planning & Services','Financial Services','Food','Health & Medical','Home Services',
                'Hotels & Travel','Local Flavor','Local Services','Mass Media','Nightlife',
                'Pets','Professional Services','Public Services & Government','Real Estate','Religious Organizations',
                'Restaurants','Shopping']

category_count.append( category_find[ category_find['categories'].str.contains('Active Life')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Arts & Entertainment')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Automotive')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Beauty & Spas')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Education')].count() )

category_count.append( category_find[ category_find['categories'].str.contains('Event Planning & Services')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Financial Services')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Food')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Health & Medical')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Home Services')].count() )

category_count.append( category_find[ category_find['categories'].str.contains('Hotels & Travel')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Local Flavor')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Local Services')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Mass Media')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Nightlife')].count() )

category_count.append( category_find[ category_find['categories'].str.contains('Pets')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Professional Services')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Public Services & Government')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Real Estate')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Religious Organizations')].count() )

category_count.append( category_find[ category_find['categories'].str.contains('Restaurants')].count() )
category_count.append( category_find[ category_find['categories'].str.contains('Shopping')].count() )

category_stat = pd.DataFrame.from_dict(category_count)
category_stat = category_stat.rename(columns = {'categories':'Counts'})

category_stat.index = category_name
category_stat
# Out:
# Total number of business in the dataset:  (85901, 2)
# Total number of unique categories:  11054
#                               Counts  stars
# Active Life                     3455   3455
# Arts & Entertainment            2447   2447
# Automotive                      4888   4888
# Beauty & Spas                   7490   7490
# Education                        877    877
# Event Planning & Services       3237   3237
# Financial Services              1112   1112
# Food                           13474  13474
# Health & Medical                6106   6106
# Home Services                   5866   5866
# Hotels & Travel                 2673   2673
# Local Flavor                     204    204
# Local Services                  4041   4041
# Mass Media                       108    108
# Nightlife                       5507   5507
# Pets                            1664   1664
# Professional Services           1080   1080
# Public Services & Government     573    573
# Real Estate                     1717   1717
# Religious Organizations          244    244
# Restaurants                    26729  26729
# Shopping                       12444  12444

# %%
# Figure: How many categories are in Yelp reviews
fig_category = {
    'data': [{'labels': category_stat.index,
              'values': category_stat.Counts,
              'type': 'pie'}],
    'layout': {'title': 'The categories of business that are reviewed in Yelp'}
     }

py.iplot(fig_category, filename='counts_of_categories')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/124.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Not just restaurants! Yelp reviews include plenty of categories of business.
# There are 22 main categories. Top 5 categories of bussiness are:
# - 25.2% of business in the dataset are categoried as "Restaurants"
# - 12.7% of business in the dataset are categoried as "Food"
# - 7.07% of business in the dataset are categoried as "Shopping"
# - 5.76% of business in the dataset are categoried as "Beauty & Spas"
# - 5.54% of business in the dataset are categoried as "Health & Medical"

# %%
restaurants = category_find[ category_find['categories'].str.contains('Restaurants')]
print 'Total number of unique categories: ', len( restaurants.categories.unique() )
# Out:
# Total number of unique categories:  4318

# %%
# number of stars of all business
stars_all = raw_business[['stars','name']]
star_distribute = stars_all.groupby(['stars']).count()
print "Mean value of the stars = ",raw_business['stars'].mean() 
star_distribute = star_distribute.rename(columns = {'name':'Counts'})
# star_distribute = star_distribute.sort_values(['stars'], ascending=False)
star_distribute
# Out:
# Mean value of the stars =  3.69485221359
#        Counts
# stars
# 1.0      1072
# 1.5      1890
# 2.0      3777
# 2.5      7447
# 3.0     11023
# 3.5     16624
# 4.0     17456
# 4.5     13648
# 5.0     12964

# %%
# Figure:Star distribution in Yelp business
fig_star_distribute = {
    'data': [{'labels': star_distribute.index,
              'values': star_distribute.Counts,
              'type': 'pie'}],
    'layout': {'title': 'Stars Distribution of all the reviewed business in Yelp'}
     }

py.iplot(fig_star_distribute, filename='Satrs_distribution')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/126.embed" height="525px" width="100%"></iframe>

# %%
trace_backers = go.Bar(
    x= star_distribute.index,
    y= star_distribute.Counts,
    marker=dict(
        color='rgba(55, 128, 191, 0.7)',
        line=dict(color='rgba(55, 128, 191, 1.0)',width=2)),
        
)

data_backers = [trace_backers]
layout = go.Layout(
    title='Star vs. Number of Business',
    font=dict(family='Arial', size=18,color='rgb(0, 0, 0)'),
    xaxis=dict(
        title='Star Rating',
        titlefont=dict(
            size=16,
            color='rgb(15, 15, 15)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    yaxis=dict(
        title='Number of Bsuiness',
        titlefont=dict(
            size=16,
            color='rgb(15, 15, 15)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    bargap=0.15,
    annotations = [dict(
            x=xi,
            y=yi,
            text=str(format(yi,',')),
            font=dict(family='Arial', size=14,color='rgba(66, 119, 244, 1)'),
            xanchor='auto',
            yanchor='bottom',
            showarrow=False,
        ) for xi, yi in zip(star_distribute.index, star_distribute.Counts)]
)

fig_backers = go.Figure(data=data_backers, layout=layout)
py.iplot(fig_backers, filename='basic-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## The stars in Yelp review
# - The mean value of the star in the reviewed business are 3.69.
# - The star of 51.3% reviews are higher than 4.
# - The rating is a bit high.

# %%
# number of stars in top 10 categories
stars_category01 = category_find[ category_find['categories'].str.contains('Active Life')].stars
stars_category02 = category_find[ category_find['categories'].str.contains('Arts & Entertainment')].stars
stars_category03 = category_find[ category_find['categories'].str.contains('Automotive')].stars
stars_category04 = category_find[ category_find['categories'].str.contains('Beauty & Spas')].stars
stars_category05 = category_find[ category_find['categories'].str.contains('Education')].stars

stars_category06 = category_find[ category_find['categories'].str.contains('Event Planning & Services')].stars
stars_category07 = category_find[ category_find['categories'].str.contains('Financial Services')].stars
stars_category08 = category_find[ category_find['categories'].str.contains('Food')].stars
stars_category09 = category_find[ category_find['categories'].str.contains('Health & Medical')].stars
stars_category10 = category_find[ category_find['categories'].str.contains('Home Services')].stars

stars_category11 = category_find[ category_find['categories'].str.contains('Hotels & Travel')].stars
stars_category12 = category_find[ category_find['categories'].str.contains('Local Flavor')].stars
stars_category13 = category_find[ category_find['categories'].str.contains('Local Services')].stars
stars_category14 = category_find[ category_find['categories'].str.contains('Mass Media')].stars
stars_category15 = category_find[ category_find['categories'].str.contains('Nightlife')].stars

stars_category16 = category_find[ category_find['categories'].str.contains('Pets')].stars
stars_category17 = category_find[ category_find['categories'].str.contains('Professional Services')].stars
stars_category18 = category_find[ category_find['categories'].str.contains('Public Services & Government')].stars
stars_category19 = category_find[ category_find['categories'].str.contains('Real Estate')].stars
stars_category20 = category_find[ category_find['categories'].str.contains('Religious Organizations')].stars

stars_category21 = category_find[ category_find['categories'].str.contains('Restaurants')].stars
stars_category22 = category_find[ category_find['categories'].str.contains('Shopping')].stars

# category_name = ['Active Life', 'Arts & Entertainment','Automotive','Beauty & Spas','Education',
#                 'Event Planning & Services','Financial Services','Food','Health & Medical','Home Services',
#                 'Hotels & Travel','Local Flavor','Local Services','Mass Media','Nightlife',
#                 'Pets','Professional Services','Public Services & Government','Real Estate','Religious Organizations',
#                 'Restaurants','Shopping']
# star_list =[]
# for i in range( 0, len(category_name) ): 
#      star_list[i] = category_find[ category_find['categories'].str.contains( category_name[i] )].stars

# %%
star_x = category_name

star_y = [stars_category01, stars_category02, stars_category03, stars_category04, stars_category05,  
          stars_category06, stars_category07, stars_category08, stars_category09, stars_category10, 
          stars_category11, stars_category12, stars_category13, stars_category14, stars_category15, 
          stars_category16, stars_category17, stars_category18, stars_category19, stars_category20, 
          stars_category21, stars_category22]

# colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)',
#          'rgba(123, 34, 23, 0.5)', 'rgba(27,66, 45, 0.5)', 'rgba(73, 126, 12, 0.5)', 'rgba(67, 210, 56, 0.5)']

traces = []

for xd, yd in zip(star_x, star_y):
        traces.append(go.Box(
            y=yd,
            name=xd,
#             boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
#             fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
        ))

layout = go.Layout(
    title='Stars Distribution for each category',
    yaxis=dict(
        autorange=True,
        showgrid=True,
        zeroline=True,
        dtick=5,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
        zerolinecolor='rgb(255, 255, 255)',
        zerolinewidth=2,
    ),
    margin=dict(
        l=40,
        r=30,
        b=120,
        t=100,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
    showlegend=False
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig,filename='Stars Distribution for each category')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yu.yuanpeng/128.embed" height="525px" width="100%"></iframe>

# %%
# find business_id by indicating the name of category
# Enter the name of categories that you would like to find

BID_by_category = raw_business[['categories','business_id','stars']]
target = u'Breakfast & Brunch' # Enter the name of categories that you would like to find
BID_by_category[ BID_by_category['categories'].str.contains(target)]
# Out:
#                                               categories  \
# 12     [u'Burgers', u'Breakfast & Brunch', u'American...
# 18     [u'Breakfast & Brunch', u'Sandwiches', u'Resta...
# 28     [u'Breakfast & Brunch', u'American (Traditiona...
# 93     [u'Burgers', u'Breakfast & Brunch', u'Diners',...
# 311    [u'Breakfast & Brunch', u'Diners', u'Restauran...
# 370    [u'Food', u'Sandwiches', u'Bagels', u'Breakfas...
# 563    [u'Breakfast & Brunch', u'American (Traditiona...
# 580    [u'Breakfast & Brunch', u'Sandwiches', u'Resta...
# 664    [u'Food', u'Sandwiches', u'Bagels', u'Breakfas...
# 669    [u'Food', u'Tea Rooms', u'Breakfast & Brunch',...
# 696              [u'Breakfast & Brunch', u'Restaurants']
# 698    [u'Breakfast & Brunch', u'Creperies', u'French...
# 790              [u'Breakfast & Brunch', u'Restaurants']
# 889    [u'Food', u'Sandwiches', u'Bagels', u'Breakfas...
# 933    [u'American (Traditional)', u'Hot Dogs', u'Bre...
# 986    [u'Breakfast & Brunch', u'American (New)', u'S...
# 1025   [u'Food', u'Sandwiches', u'Bagels', u'Breakfas...
# 1067   [u'Breakfast & Brunch', u'American (Traditiona...
# 1175   [u'Breakfast & Brunch', u'American (Traditiona...
# 1242             [u'Breakfast & Brunch', u'Restaurants']
# 1261   [u'Breakfast & Brunch', u'American (Traditiona...
# 1298   [u'Breakfast & Brunch', u'American (Traditiona...
# 1338             [u'Breakfast & Brunch', u'Restaurants']
# 1367             [u'Breakfast & Brunch', u'Restaurants']
# 1386   [u'Breakfast & Brunch', u'American (Traditiona...
# 1415   [u'Breakfast & Brunch', u'American (Traditiona...
# 1420   [u'Breakfast & Brunch', u'American (Traditiona...
# 1469   [u'Breakfast & Brunch', u'American (Traditiona...
# 1526   [u'Food', u'Sandwiches', u'Bagels', u'Breakfas...
# 1542   [u'Burgers', u'Breakfast & Brunch', u'American...
# ...                                                  ...
# 85221  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85235  [u'Soup', u'Breakfast & Brunch', u'Salad', u'R...
# 85237  [u'Delis', u'Waffles', u'Breakfast & Brunch', ...
# 85288  [u'American (Traditional)', u'Cafes', u'Breakf...
# 85338  [u'Bars', u'Breakfast & Brunch', u'Cocktail Ba...
# 85345  [u'Breakfast & Brunch', u'Turkish', u'Mediterr...
# 85373  [u'Breakfast & Brunch', u'American (New)', u'C...
# 85396  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85405  [u'Bars', u'Breakfast & Brunch', u'Wine Bars',...
# 85524  [u'Food', u'Breakfast & Brunch', u'Juice Bars ...
# 85529  [u'Breakfast & Brunch', u'American (New)', u'V...
# 85545  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85546  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85558  [u'Breakfast & Brunch', u'American (New)', u'M...
# 85561  [u'Cuban', u'Latin American', u'Breakfast & Br...
# 85602  [u'Food', u'Ice Cream & Frozen Yogurt', u'Brea...
# 85629  [u'Breakfast & Brunch', u'Cafes', u'Restaurants']
# 85638            [u'Breakfast & Brunch', u'Restaurants']
# 85650  [u'Breakfast & Brunch', u'Tapas/Small Plates',...
# 85655  [u'Food', u'Breakfast & Brunch', u'Cafes', u'D...
# 85689  [u'Breakfast & Brunch', u'Sandwiches', u'Resta...
# 85706  [u'Food', u'Coffee & Tea', u'Breakfast & Brunc...
# 85747  [u'Breakfast & Brunch', u'American (Traditiona...
# 85771  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85772  [u'Breakfast & Brunch', u'Cafes', u'American (...
# 85782  [u'Bars', u'Breakfast & Brunch', u'Pubs', u'Ni...
# 85794  [u'Bars', u'Breakfast & Brunch', u'Cocktail Ba...
# 85839  [u'Burgers', u'Breakfast & Brunch', u'American...
# 85889  [u'Breakfast & Brunch', u'American (New)', u'R...
# 85890  [u'Bars', u'American (Traditional)', u'Breakfa...
#
#                   business_id  stars
# 12     wJr6kSA5dchdgOdwH6dZ2w    3.5
# 18     b9WZJp5L1RZr4F1nxclOoQ    4.5
# 28     wqu7ILomIOPSduRwoWp4AQ    3.5
# 93     r8BwdblCW-ZUES37BL0khw    4.5
# 311    2Igiyhi82R8_QaaPplRmCw    4.5
# 370    uwiD9jxs09xxXG0by_xKuA    3.0
# 563                    #NAME?    3.5
# 580    o_wRqOpli9kyZGXlJtLLdA    4.0
# 664    sQWSHCIH_HUT4HUXaxDaBA    3.0
# 669    rUQfZOengMpXFkLvJrNJ3g    4.5
# 696    TxKmAsKQjND5vbhBdUSyIA    4.0
# 698    cmGR1HS9ms233roSllcglw    4.0
# 790    cbLaFQJOfzDy_TxMkPee9Q    4.0
# 889    Gw5POFxBRoJxN_ZYhk6lgQ    4.0
# 933    LT0AgHTpDifuHSXgyLmJwg    3.5
# 986                    #NAME?    3.5
# 1025   LUylwiKNsS7_iumytRgAmw    3.0
# 1067   b856Q36EWKbwbm_XdJER8Q    3.0
# 1175   CE6TWiZ1hraCilyXIfxu4w    4.0
# 1242   xP-6TN10JA_7C6-V1-JOEQ    3.5
# 1261   hIQRiE3UsYH7UsrsDwJwLA    3.0
# 1298   UzMMpUFwJhwUkHOyeXeWsQ    4.0
# 1338   KQqkkg5jaxIbdMIG4MJCIw    4.0
# 1367                   #NAME?    3.5
# 1386   0sbPpUIyTpcx90bLRsVx0w    4.0
# 1415   27cIh0prWEOO2anhGx2G8A    4.5
# 1420   687wG68J1XicP5YzMqKqFQ    3.0
# 1469   ttsxQ4P_jEqKLxwkLUI8_w    3.0
# 1526   zOY-W35waCcBWDmjX7_MFQ    4.0
# 1542   _91N3Q_MB5Nula56ZWXzSA    2.0
# ...                       ...    ...
# 85221  SHLghUxGeWQdm-w2hutd8A    3.0
# 85235  aEMLvqvFt9QfOnEAqIMsvA    4.0
# 85237  jRPtR43eLXJmnr9Mw_deMg    3.0
# 85288  13QT4GjYFy9c1gmRwV-kLA    3.0
# 85338  srpJ5boG_0634LjLur2GqQ    4.5
# 85345  NEhs_aeHR7Tld6qdheisAw    4.5
# 85373  PKzibcuFC-ZBfAvYC0w_vw    4.0
# 85396  7PPt2xMynVprZ5jVAwhO9w    3.5
# 85405  0DR0OOVju_ZoPNVzneEQbQ    4.0
# 85524  vytvnvnvN2lXirpYvjHDkQ    4.5
# 85529  lZkE97CKQSTCWgl99Cu-RQ    4.0
# 85545  HAJ0BmzOUI-c9_afStHnlA    4.0
# 85546  SccVYXRp937NZpco33StFg    3.5
# 85558  iCPztCT1ok0Rv9K5dYK5kw    4.0
# 85561  4QiRy3zCKxfguCm8BntB1g    4.0
# 85602  WQLVY0YY4oBoXMtf5J0llw    5.0
# 85629  rVtnORd1uP2RZTkQGGvSWw    4.5
# 85638  lNbD5zcd86UYGXmTchRdbA    4.5
# 85650  Oo7iPVeUYzYK5gEnOYOe6g    5.0
# 85655  mxlmK_OR51PNzVTXi96q0Q    4.5
# 85689  b_XFQuphwM2KuA_RXMv02A    3.5
# 85706  qMBPVlKkT-hDcIGi1wkswg    4.0
# 85747  ZH1qKYHRcaSfX3aeN8lt2g    4.0
# 85771  KVpiG6W7P0gZdv6-zFd3zA    4.0
# 85772  M_IX2Uc7JW93FQIOWXcDjA    4.5
# 85782  mILWoahc7G29kTlWHcZpXg    5.0
# 85794  Rz3QHbwQq6wDR-GlaRFuSQ    3.5
# 85839  HbpDgyreo7QzgWf4Dpx68Q    4.5
# 85889  TFCPmrQj9PD1WvnZGYO85Q    3.5
# 85890  hNX62vEzvdVsMUMmYYHoPQ    2.0
#
# [1609 rows x 3 columns]

# %% [markdown]
# ### Review & advise from TA
#
# narrow doen the topic
# give some hypothesis and verify it.
# Find impact reviewers.
# k-min clustering
#
#
# 1. Does the review from impact users (stars)?
# 2. fans & stars
#
# string literal_eval
#
# 1. Find the fake review.
# Observe the activity of user.
#
# 2. Find an impactful review: after a specific date(3~7days), the reviews increase.
# The influence of power users & power reviews
#
# 3. web search for user, review, and business. Give prediction of the trend.
